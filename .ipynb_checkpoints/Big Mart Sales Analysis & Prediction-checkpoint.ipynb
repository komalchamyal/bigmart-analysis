# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("Train.csv")
dataset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %% [markdown]
# # EDA

# %%
dataset.describe()
dataset.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
dataset.apply(lambda x: len(x.unique()))
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
#check categorical variables
cat_col=[]
for x in dataset.dtypes.index:
    if dataset.dtypes[x]=="object":
        cat_col.append(x)
for col in cat_col:
    print(col)
    print(dataset[col].value_counts())
    print()
# Out:
# Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# Outlet_Identifier
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64
#
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
dataset[["Outlet_Location_Type","Item_Outlet_Sales"]].groupby(by="Outlet_Location_Type").sum()
# Out:
#                       Item_Outlet_Sales
# Outlet_Location_Type
# Tier 1                     4.482059e+06
# Tier 2                     6.472314e+06
# Tier 3                     7.636753e+06

# %%
# dataset.groupby(by="Outlet_Location_Type").count()
# dataset.pivot_table(index='Outlet_Identifier',values=["Outlet_Location_Type"], aggfunc=

# %%
df.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df.loc[(df['Item_Fat_Content']=='LF') | (df['Item_Fat_Content']=='low fat') | (df['Item_Fat_Content']=='LOW'),'Item_Fat_Content']='Low Fat'
df.loc[(df['Item_Fat_Content']=='reg'),'Item_Fat_Content']='Regular'
df.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %% [markdown]
# ## Null Values

# %%
df=dataset

# %%
# dataset.iloc[1,1]=None
df.isnull().sum()
# round(dataset.isnull().sum()*100/len(dataset),2)
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df["Item_Weight"].mean()
# Out:
# 12.857645184135976

# %%
df["Item_Weight"]=df[["Item_Weight"]].fillna(df["Item_Weight"].mean())

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.pivot_table(index='Item_Identifier', columns="Outlet_Type", aggfunc='mean')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_43728\3744572504.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df.pivot_table(index='Item_Identifier', columns="Outlet_Type", aggfunc='mean')
#                      Item_MRP                                      \
# Outlet_Type     Grocery Store Supermarket Type1 Supermarket Type2
# Item_Identifier
# DRA12                143.0154        141.540400          142.0154
# DRA24                163.5868        163.911800               NaN
# DRA59                185.1424        184.467400          186.5924
# DRB01                     NaN        189.353000               NaN
# DRB13                189.0530        189.853000               NaN
# ...                       ...               ...               ...
# NCZ30                121.4098        120.389800               NaN
# NCZ41                     NaN        125.495400          126.1704
# NCZ42                238.3248        236.224800               NaN
# NCZ53                188.7214        187.921400          186.6214
# NCZ54                161.2552        161.921867          163.4552
#
#                                   Item_Outlet_Sales                    \
# Outlet_Type     Supermarket Type3     Grocery Store Supermarket Type1
# Item_Identifier
# DRA12                         NaN          283.6308        2481.76950
# DRA24                    165.7868          409.4670        2497.74870
# DRA59                    186.6924          370.1848        2174.83570
# DRB01                    190.0530               NaN        1992.40650
# DRB13                         NaN          948.7650        2798.85675
# ...                           ...               ...               ...
# NCZ30                    121.9098          241.0196        1807.64700
# NCZ41                         NaN               NaN        1814.97080
# NCZ42                         NaN          711.0744        4621.98360
# NCZ53                    190.4214          376.8428        3580.00660
# NCZ54                    164.0552          243.6828        4711.20080
#
#                                                     Item_Visibility  \
# Outlet_Type     Supermarket Type2 Supermarket Type3   Grocery Store
# Item_Identifier
# DRA12                    850.8924               NaN        0.068535
# DRA24                         NaN         4913.6040        0.068370
# DRA59                   4442.2176         7033.5112        0.219055
# DRB01                         NaN          569.2590             NaN
# DRB13                         NaN               NaN        0.011791
# ...                           ...               ...             ...
# NCZ30                         NaN         3374.2744        0.043828
# NCZ41                   1877.5560               NaN             NaN
# NCZ42                         NaN               NaN        0.000000
# NCZ53                   1884.2140         5652.6420        0.040970
# NCZ54                   2599.2832         5523.4768        0.072976
#
#                                                                        \
# Outlet_Type     Supermarket Type1 Supermarket Type2 Supermarket Type3
# Item_Identifier
# DRA12                    0.020522          0.041113               NaN
# DRA24                    0.039990               NaN          0.039735
# DRA59                    0.095969          0.128449          0.127308
# DRB01                    0.082269               NaN          0.081841
# DRB13                    0.007055               NaN               NaN
# ...                           ...               ...               ...
# NCZ30                    0.020961               NaN          0.026058
# NCZ41                    0.064529          0.000000               NaN
# NCZ42                    0.011305               NaN               NaN
# NCZ53                    0.024486          0.024577          0.024359
# NCZ54                    0.083459          0.083699          0.082956
#
#                   Item_Weight                                      \
# Outlet_Type     Grocery Store Supermarket Type1 Supermarket Type2
# Item_Identifier
# DRA12               11.600000            11.600             11.60
# DRA24               16.103823            19.350               NaN
# DRA59               10.563823             8.270              8.27
# DRB01                     NaN             7.390               NaN
# DRB13                6.115000             6.115               NaN
# ...                       ...               ...               ...
# NCZ30                6.590000             6.590               NaN
# NCZ41                     NaN            19.850             19.85
# NCZ42               10.500000            10.500               NaN
# NCZ53                9.600000             9.600              9.60
# NCZ54               13.753823            14.650             14.65
#
#                                   Outlet_Establishment_Year                    \
# Outlet_Type     Supermarket Type3             Grocery Store Supermarket Type1
# Item_Identifier
# DRA12                         NaN                    1998.0       2000.000000
# DRA24                   12.857645                    1991.5       1999.250000
# DRA59                   12.857645                    1991.5       1997.500000
# DRB01                   12.857645                       NaN       1993.000000
# DRB13                         NaN                    1998.0       1999.250000
# ...                           ...                       ...               ...
# NCZ30                   12.857645                    1998.0       1999.800000
# NCZ41                         NaN                       NaN       2000.000000
# NCZ42                         NaN                    1998.0       1999.250000
# NCZ53                   12.857645                    1998.0       1993.000000
# NCZ54                   12.857645                    1991.5       1999.333333
#
#
# Outlet_Type     Supermarket Type2 Supermarket Type3
# Item_Identifier
# DRA12                      2009.0               NaN
# DRA24                         NaN            1985.0
# DRA59                      2009.0            1985.0
# DRB01                         NaN            1985.0
# DRB13                         NaN               NaN
# ...                           ...               ...
# NCZ30                         NaN            1985.0
# NCZ41                      2009.0               NaN
# NCZ42                         NaN               NaN
# NCZ53                      2009.0            1985.0
# NCZ54                      2009.0            1985.0
#
# [1559 rows x 20 columns]

# %%
sns.scatterplot(data=dataset[["Outlet_Size", "Outlet_Type"]],x="Outlet_Size", y="Outlet_Type")
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Outlet_Type'>

# %%
df.groupby(by="Outlet_Type").count()
# Out:
#                    Item_Identifier  Item_Weight  Item_Fat_Content  \
# Outlet_Type
# Grocery Store                 1083         1083              1083
# Supermarket Type1             5577         5577              5577
# Supermarket Type2              928          928               928
# Supermarket Type3              935          935               935
#
#                    Item_Visibility  Item_Type  Item_MRP  Outlet_Identifier  \
# Outlet_Type
# Grocery Store                 1083       1083      1083               1083
# Supermarket Type1             5577       5577      5577               5577
# Supermarket Type2              928        928       928                928
# Supermarket Type3              935        935       935                935
#
#                    Outlet_Establishment_Year  Outlet_Size  \
# Outlet_Type
# Grocery Store                           1083          528
# Supermarket Type1                       5577         3722
# Supermarket Type2                        928          928
# Supermarket Type3                        935          935
#
#                    Outlet_Location_Type  Item_Outlet_Sales
# Outlet_Type
# Grocery Store                      1083               1083
# Supermarket Type1                  5577               5577
# Supermarket Type2                   928                928
# Supermarket Type3                   935                935

# %%
sns.scatterplot(data=dataset[["Outlet_Identifier", "Outlet_Type"]],y="Outlet_Identifier", x="Outlet_Type")
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Outlet_Identifier'>

# %%
sns.scatterplot(data=dataset[["Outlet_Size", "Outlet_Type"]],x="Outlet_Size", y="Outlet_Type")
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Outlet_Type'>

# %%
data=df[["Outlet_Type","Outlet_Size"]]
# len(x_train.index[x_train.Outlet_Size.isnull()])
train_data=data.drop(data.index[data.Outlet_Size.isnull()], axis=0)
x_train=train_data[["Outlet_Type"]]
y_train=train_data[["Outlet_Size"]]
# y_train

# %%
x_test=data.drop(data.index[data.Outlet_Size.notnull()], axis=0)
x_test
# Out:
#             Outlet_Type Outlet_Size
# 3         Grocery Store         NaN
# 8     Supermarket Type1         NaN
# 9     Supermarket Type1         NaN
# 25    Supermarket Type1         NaN
# 28        Grocery Store         NaN
# ...                 ...         ...
# 8502  Supermarket Type1         NaN
# 8508  Supermarket Type1         NaN
# 8509      Grocery Store         NaN
# 8514  Supermarket Type1         NaN
# 8519  Supermarket Type1         NaN
#
# [2410 rows x 2 columns]

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
# nb.fit(x_train, y_train)

# %%
y_train=pd.get_dummies(y_train)

# %%
x_train=pd.get_dummies(x_train)

# %%
sns.pairplot(df)

# %% [markdown]
# # EDA

# %% [markdown]
# ### 1) Relationship between Item Visibility and Sale

# %% [markdown]
# #### Expected -  Positive Linear Relation

# %%
df1=dataset[["Item_Visibility", "Item_Outlet_Sales"]]

# %%
(df1.Item_Visibility==0).sum()*100/len(df)
# 6% Items have zero visibility
# are they still getting sold??
# Out:
# 6.1715358441863195

# %% [markdown]
# Items with zero visibility don't make sense, especially when they are being sold irrespective of zero visibility

# %% [markdown]
# Inference??

# %%
# df1.drop(df1.index([df1["Item_Visibility"]==0]))
df1=df1.drop(df1[df1["Item_Visibility"]==0].index)

# %%
# dataset[["Item_Visibility", "Item_Outlet_Sales"]].plot.scatter(x=0, y=1)
sns.scatterplot(data=df1,x="Item_Visibility", y="Item_Outlet_Sales", hue="Item_Outlet_Sales")
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# #### Actual - Don't Understand

# %% [markdown]
# ### Relationship between Item visibility and MRP

# %%
# dataset[["Item_Visibility", "Item_Outlet_Sales"]].plot.scatter(x=0, y=1)
sns.scatterplot(data=dataset[["Item_Visibility", "Item_MRP"]],x="Item_Visibility", y="Item_MRP")

# %%
sns.histplot(data=dataset[["Item_MRP"]])

# %%
sns.catplot(data=dataset[["Item_Visibility", "Item_Type"]], y="Item_Type", x="Item_Visibility")

# %% [markdown]
# ### 2) Relationship between Outlet Size and Sale

# %% [markdown]
# #### Expected - Positive Relationship

# %%
x=dataset[["Outlet_Size", "Item_Outlet_Sales"]]
x=x.dropna()
x

# %%
x.plot.scatter(y="Item_Outlet_Sales", x='Outlet_Size')

# %%
x.groupby('Outlet_Size').sum()

# %%
x.groupby('Outlet_Size').sum().plot()

# %% [markdown]
# #### Result - Medium sized stores have the highest item sales

# %% [markdown]
# # Item type

# %%
df.groupby(by=['Item_Identifier', 'Item_MRP', 'Outlet_Type']).first()
# Out:
#                                             Item_Weight Item_Fat_Content  \
# Item_Identifier Item_MRP Outlet_Type
# DRA12           140.3154 Supermarket Type1    11.600000          Low Fat
#                 141.6154 Supermarket Type1    11.600000          Low Fat
#                 141.9154 Supermarket Type1    11.600000          Low Fat
#                 142.0154 Supermarket Type2    11.600000          Low Fat
#                 142.3154 Supermarket Type1    11.600000          Low Fat
# ...                                                 ...              ...
# NCZ54           161.5552 Grocery Store        14.650000          Low Fat
#                 161.9552 Supermarket Type1    14.650000          Low Fat
#                 162.4552 Supermarket Type1    14.650000          Low Fat
#                 163.4552 Supermarket Type2    14.650000          Low Fat
#                 164.0552 Supermarket Type3    12.857645          Low Fat
#
#                                             Item_Visibility    Item_Type  \
# Item_Identifier Item_MRP Outlet_Type
# DRA12           140.3154 Supermarket Type1         0.041178  Soft Drinks
#                 141.6154 Supermarket Type1         0.000000  Soft Drinks
#                 141.9154 Supermarket Type1         0.000000  Soft Drinks
#                 142.0154 Supermarket Type2         0.041113  Soft Drinks
#                 142.3154 Supermarket Type1         0.040912  Soft Drinks
# ...                                                     ...          ...
# NCZ54           161.5552 Grocery Store             0.000000    Household
#                 161.9552 Supermarket Type1         0.083359    Household
#                 162.4552 Supermarket Type1         0.083528    Household
#                 163.4552 Supermarket Type2         0.083699    Household
#                 164.0552 Supermarket Type3         0.082956    Household
#
#                                            Outlet_Identifier  \
# Item_Identifier Item_MRP Outlet_Type
# DRA12           140.3154 Supermarket Type1            OUT017
#                 141.6154 Supermarket Type1            OUT045
#                 141.9154 Supermarket Type1            OUT035
#                 142.0154 Supermarket Type2            OUT018
#                 142.3154 Supermarket Type1            OUT013
# ...                                                      ...
# NCZ54           161.5552 Grocery Store                OUT010
#                 161.9552 Supermarket Type1            OUT046
#                 162.4552 Supermarket Type1            OUT045
#                 163.4552 Supermarket Type2            OUT018
#                 164.0552 Supermarket Type3            OUT027
#
#                                             Outlet_Establishment_Year  \
# Item_Identifier Item_MRP Outlet_Type
# DRA12           140.3154 Supermarket Type1                       2007
#                 141.6154 Supermarket Type1                       2002
#                 141.9154 Supermarket Type1                       2004
#                 142.0154 Supermarket Type2                       2009
#                 142.3154 Supermarket Type1                       1987
# ...                                                               ...
# NCZ54           161.5552 Grocery Store                           1998
#                 161.9552 Supermarket Type1                       1997
#                 162.4552 Supermarket Type1                       2002
#                 163.4552 Supermarket Type2                       2009
#                 164.0552 Supermarket Type3                       1985
#
#                                            Outlet_Size Outlet_Location_Type  \
# Item_Identifier Item_MRP Outlet_Type
# DRA12           140.3154 Supermarket Type1        None               Tier 2
#                 141.6154 Supermarket Type1        None               Tier 2
#                 141.9154 Supermarket Type1       Small               Tier 2
#                 142.0154 Supermarket Type2      Medium               Tier 3
#                 142.3154 Supermarket Type1        High               Tier 3
# ...                                                ...                  ...
# NCZ54           161.5552 Grocery Store            None               Tier 3
#                 161.9552 Supermarket Type1       Small               Tier 1
#                 162.4552 Supermarket Type1        None               Tier 2
#                 163.4552 Supermarket Type2      Medium               Tier 3
#                 164.0552 Supermarket Type3      Medium               Tier 3
#
#                                             Item_Outlet_Sales
# Item_Identifier Item_MRP Outlet_Type
# DRA12           140.3154 Supermarket Type1          2552.6772
#                 141.6154 Supermarket Type1          3829.0158
#                 141.9154 Supermarket Type1           992.7078
#                 142.0154 Supermarket Type2           850.8924
#                 142.3154 Supermarket Type1          2552.6772
# ...                                                       ...
# NCZ54           161.5552 Grocery Store               324.9104
#                 161.9552 Supermarket Type1          4711.2008
#                 162.4552 Supermarket Type1          2274.3728
#                 163.4552 Supermarket Type2          2599.2832
#                 164.0552 Supermarket Type3          5523.4768
#
# [8318 rows x 9 columns]

# %%
sns.catplot(data=df, x="Item_Identifier", y="Outlet_Type")

# %% [markdown]
# # Predict Outlet Type

# %% [markdown]
# # Pandas Profiling

# %%
import sys
# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !jupyter nbextension enable --py widgetsnbextension

# %%
from ydata_profiling import ProfileReport

df = pd.DataFrame(dataset)
profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
profile.to_widgets()

# %%
profile.to_file("your_report.html")
